# %%
# !mamba install -c conda-forge nodejs jupyterlab-lsp python-lsp-server jupysql psycopg2 -y
# !npm install -g sql-language-server
# !sql-language-server --version

import subprocess
process = subprocess.Popen(["sql-language-server", "up"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# %load_ext sql
# Out:
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# DEPRECATION: --no-python-version-warning is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to remove the flag as it's a no-op. Discussion can be found at https://github.com/pypa/pip/issues/13154
#
# Pinned packages:
#
#   - python=3.12
#
# Pinned packages:
#
#   - python=3.12
#
#
# Transaction
#
#   Prefix: /opt/conda
#
#   Updating specs:
#
#    - nodejs
#    - jupyterlab-lsp
#    - python-lsp-server
#    - jupysql
#    - psycopg2
#
#
#   Package                   Version  Build            Channel          Size
# ─────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────
#
#   + astroid                   3.3.8  py312h7900ff3_0  conda-forge     507kB
#   + autopep8                  2.0.4  pyhd8ed1ab_0     conda-forge      46kB
#   + backoff                   2.2.1  pyhd8ed1ab_1     conda-forge      19kB
#   + cyrus-sasl               2.1.27  h54b06d7_7       conda-forge     220kB
#   + docstring-to-markdown      0.15  pyhd8ed1ab_1     conda-forge      34kB
#   + flake8                    7.1.1  pyhd8ed1ab_1     conda-forge     111kB
#   + isort                     6.0.0  pyhd8ed1ab_0     conda-forge      75kB
#   + jupysql                 0.10.17  pyhd8ed1ab_0     conda-forge      80kB
#   + jupysql-plugin            0.4.5  pyhd8ed1ab_0     conda-forge     171kB
#   + jupyterlab-lsp            5.1.0  pyhd8ed1ab_3     conda-forge     605kB
#   + libntlm                     1.8  hb9d3cd8_0       conda-forge      33kB
#   + libpq                      17.2  h3b95a9b_1       conda-forge       3MB
#   + mccabe                    0.7.0  pyhd8ed1ab_1     conda-forge      13kB
#   + monotonic                   1.6  pyhd8ed1ab_0     conda-forge      13kB
#   + nodejs                  22.12.0  hf235a45_0       conda-forge      22MB
#   + openldap                  2.6.9  he970967_0       conda-forge     784kB
#   + ploomber-core            0.2.26  pyhd8ed1ab_0     conda-forge      29kB
#   + posthog                   3.6.5  pyhd8ed1ab_0     conda-forge      50kB
#   + prettytable              3.14.0  pyhd8ed1ab_0     conda-forge      33kB
#   + psycopg2                  2.9.9  py312hfaedaf9_2  conda-forge     190kB
#   + pycodestyle              2.12.1  pyhd8ed1ab_1     conda-forge      34kB
#   + pydocstyle                6.3.0  pyhd8ed1ab_1     conda-forge      40kB
#   + pyflakes                  3.2.0  pyhd8ed1ab_1     conda-forge      58kB
#   + pylint                    3.3.4  pyh29332c3_0     conda-forge     380kB
#   + python-lsp-jsonrpc        1.1.2  pyhff2d567_1     conda-forge      14kB
#   + python-lsp-server        1.12.2  pyhff2d567_0     conda-forge       7kB
#   + python-lsp-server-base   1.12.2  pyhd8ed1ab_0     conda-forge      61kB
#   + pytoolconfig              1.2.5  pyhd8ed1ab_1     conda-forge      22kB
#   + rope                     1.13.0  pyhd8ed1ab_1     conda-forge     150kB
#   + snowballstemmer           2.2.0  pyhd8ed1ab_0     conda-forge      59kB
#   + sqlglot                  26.0.1  pyhd8ed1ab_0     conda-forge     310kB
#   + sqlparse                  0.5.3  pyhd8ed1ab_0     conda-forge      40kB
#   + tomlkit                  0.13.2  pyha770c72_1     conda-forge      37kB
#   + ujson                    5.10.0  py312h2ec8cdc_1  conda-forge      52kB
#   + whatthepatch              1.0.7  pyhd8ed1ab_1     conda-forge      17kB
#   + yapf                     0.43.0  pyhd8ed1ab_1     conda-forge     179kB
#
#   Summary:
#
#   Install: 36 packages
#
#   Total download: 29MB
#
# ─────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# [+] 0.0s
# Downloading      ╸━━━━━━━━━━━━━━━━━━━━━━   0.0 B                            0.0s
# Extracting       -----------------------       0                            0.0s[+] 0.1s
# Downloading  (5) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B astroid                    0.0s
# Extracting       -----------------------       0                            0.0sopenldap                                           784.5kB @   1.2MB/s  0.1s
# [+] 0.2s
# Downloading  (5) ━━━━━━━━━━━━━━━━━━━━━━━   1.3MB astroid                    0.1s
# Extracting   (1) -----------------------       0 openldap                   0.0sjupyterlab-lsp                                     604.9kB @ 830.6kB/s  0.1s
# astroid                                            506.8kB @   2.1MB/s  0.2s
# [+] 0.3s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB cyrus-sasl                 0.2s
# Extracting   (3) -----------------------       0 openldap                   0.1s[+] 0.4s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB cyrus-sasl                 0.3s
# Extracting       -----------------------       3                            0.2s[+] 0.5s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB cyrus-sasl                 0.4s
# Extracting       -----------------------       3                            0.2s[+] 0.6s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB cyrus-sasl                 0.5s
# Extracting       -----------------------       3                            0.2s[+] 0.7s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB libpq                      0.6s
# Extracting       -----------------------       3                            0.2s[+] 0.8s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB libpq                      0.7s
# Extracting       -----------------------       3                            0.2s[+] 0.9s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB libpq                      0.8s
# Extracting       -----------------------       3                            0.2s[+] 1.0s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB libpq                      0.9s
# Extracting       -----------------------       3                            0.2s[+] 1.1s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB nodejs                     1.0s
# Extracting       -----------------------       3                            0.2s[+] 1.2s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB nodejs                     1.1s
# Extracting       -----------------------       3                            0.2s[+] 1.3s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB nodejs                     1.2s
# Extracting       -----------------------       3                            0.2s[+] 1.4s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB nodejs                     1.3s
# Extracting       -----------------------       3                            0.2s[+] 1.5s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB pylint                     1.4s
# Extracting       -----------------------       3                            0.2s[+] 1.6s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB pylint                     1.5s
# Extracting       -----------------------       3                            0.2s[+] 1.7s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB pylint                     1.6s
# Extracting       -----------------------       3                            0.2s[+] 1.8s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB pylint                     1.7s
# Extracting       -----------------------       3                            0.2s[+] 1.9s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB sqlglot                    1.8s
# Extracting       -----------------------       3                            0.2s[+] 2.0s
# Downloading  (5) ━━╸━━━━━━━━━━━━━━━━━━━━   4.4MB sqlglot                    1.9s
# Extracting       -----------------------       3                            0.2slibpq                                                2.7MB @   1.3MB/s  2.0s
# sqlglot                                            310.0kB @  92.0kB/s  1.8s
# cyrus-sasl                                         219.5kB @  92.8kB/s  1.8s
# pylint                                             380.0kB @  98.5kB/s  1.8s
# psycopg2                                           189.9kB @  ??.?MB/s  0.1s
# yapf                                               179.3kB @  ??.?MB/s  0.1s
# [+] 2.1s
# Downloading  (4) ━━━━━━━━╸━━━━━━━━━━━━━━  12.2MB flake8                     2.0s
# Extracting   (6) -----------------------       3 cyrus-sasl                 0.2sjupysql-plugin                                     171.0kB @  ??.?MB/s  0.1s
# rope                                               150.1kB @  ??.?MB/s  0.1s
# flake8                                             111.2kB @  ??.?MB/s  0.0s
# jupysql                                             79.9kB @  ??.?MB/s  0.0s
# isort                                               74.5kB @  ??.?MB/s  0.1s
# python-lsp-server-base                              61.1kB @  ??.?MB/s  0.1s
# snowballstemmer                                     58.8kB @  ??.?MB/s  0.1s
# pyflakes                                            58.4kB @  ??.?MB/s  0.0s
# [+] 2.2s
# Downloading  (5) ━━━━━━━━━━━━━╸━━━━━━━━━  18.7MB autopep8                   2.1s
# Extracting   (7) -----------------------      10 flake8                     0.3sujson                                               51.8kB @  ??.?MB/s  0.1s
# posthog                                             49.6kB @ 931.0kB/s  0.1s
# autopep8                                            45.7kB @  ??.?MB/s  0.1s
# sqlparse                                            40.4kB @ 724.1kB/s  0.1s
# pydocstyle                                          40.2kB @  ??.?MB/s  0.0s
# tomlkit                                             37.4kB @ 730.4kB/s  0.1s
# pycodestyle                                         34.4kB @  ??.?MB/s  0.0s
# [+] 2.3s
# Downloading  (5) ━━━━━━━━━━━━━━━━━━━╸━━━  25.3MB docstring-to-markdown      2.2s
# Extracting   (6) -----------------------      18 autopep8                   0.4sdocstring-to-markdown                               34.0kB @  ??.?MB/s  0.0s
# nodejs                                              21.8MB @   8.1MB/s  2.3s
# libntlm                                             33.4kB @  ??.?MB/s  0.1s
# pytoolconfig                                        21.8kB @  ??.?MB/s  0.0s
# ploomber-core                                       29.4kB @ 559.6kB/s  0.1s
# prettytable                                         33.3kB @  ??.?MB/s  0.1s
# backoff                                             18.8kB @  ??.?MB/s  0.0s
# whatthepatch                                        17.0kB @  ??.?MB/s  0.0s
# python-lsp-jsonrpc                                  13.9kB @  ??.?MB/s  0.0s
# [+] 2.4s
# Downloading  (3) ━━━━━━━━━━━━━━━━━━━━━╸━  28.9MB mccabe                     2.3s
# Extracting   (8) -----------------------      25 backoff                    0.5smonotonic                                           13.4kB @  ??.?MB/s  0.0s
# mccabe                                              12.9kB @ 256.1kB/s  0.1s
# python-lsp-server                                    7.3kB @ 136.4kB/s  0.1s
# [+] 2.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     0.6s[+] 2.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     0.7s[+] 2.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     0.8s[+] 2.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     0.9s[+] 2.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     1.0s[+] 3.0s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     1.1s[+] 3.1s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     1.2s[+] 3.2s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     1.3s[+] 3.3s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     1.4s[+] 3.4s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     1.5s[+] 3.5s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     1.6s[+] 3.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     1.7s[+] 3.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  28.9MB                            2.4s
# Extracting   (1) -----------------------      35 nodejs                     1.8sLinking jupyterlab-lsp-5.1.0-pyhd8ed1ab_3
# Linking docstring-to-markdown-0.15-pyhd8ed1ab_1
# Linking mccabe-0.7.0-pyhd8ed1ab_1
# Linking pycodestyle-2.12.1-pyhd8ed1ab_1
# Linking snowballstemmer-2.2.0-pyhd8ed1ab_0
# Linking pyflakes-3.2.0-pyhd8ed1ab_1
# Linking whatthepatch-1.0.7-pyhd8ed1ab_1
# Linking yapf-0.43.0-pyhd8ed1ab_1
# Linking isort-6.0.0-pyhd8ed1ab_0
# Linking tomlkit-0.13.2-pyha770c72_1
# Linking sqlparse-0.5.3-pyhd8ed1ab_0
# Linking prettytable-3.14.0-pyhd8ed1ab_0
# Linking sqlglot-26.0.1-pyhd8ed1ab_0
# Linking pytoolconfig-1.2.5-pyhd8ed1ab_1
# Linking backoff-2.2.1-pyhd8ed1ab_1
# Linking monotonic-1.6-pyhd8ed1ab_0
# Linking autopep8-2.0.4-pyhd8ed1ab_0
# Linking pydocstyle-6.3.0-pyhd8ed1ab_1
# Linking flake8-7.1.1-pyhd8ed1ab_1
# Linking rope-1.13.0-pyhd8ed1ab_1
# Linking posthog-3.6.5-pyhd8ed1ab_0
# Linking ploomber-core-0.2.26-pyhd8ed1ab_0
# Linking jupysql-plugin-0.4.5-pyhd8ed1ab_0
# Linking jupysql-0.10.17-pyhd8ed1ab_0
# Linking nodejs-22.12.0-hf235a45_0
# Linking ujson-5.10.0-py312h2ec8cdc_1
# Linking astroid-3.3.8-py312h7900ff3_0
# Linking libntlm-1.8-hb9d3cd8_0
# Linking cyrus-sasl-2.1.27-h54b06d7_7
# Linking openldap-2.6.9-he970967_0
# Linking libpq-17.2-h3b95a9b_1
# Linking psycopg2-2.9.9-py312hfaedaf9_2
# Linking python-lsp-jsonrpc-1.1.2-pyhff2d567_1
# Linking pylint-3.3.4-pyh29332c3_0
# Linking python-lsp-server-base-1.12.2-pyhd8ed1ab_0
# Linking python-lsp-server-1.12.2-pyhff2d567_0
#
# Transaction finished
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇npm warn deprecated @npmcli/move-file@1.1.2: This functionality has been moved to @npmcli/fs
# ⠏npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠏npm warn deprecated source-map-url@0.4.1: See https://github.com/lydell/source-map-url#deprecated
# ⠏⠋npm warn deprecated npmlog@6.0.2: This package is no longer supported.
# ⠋npm warn deprecated urix@0.1.0: Please see https://github.com/lydell/urix#deprecated
# ⠋npm warn deprecated abab@2.0.6: Use your platform's native atob() and btoa() methods instead
# ⠙npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠙npm warn deprecated resolve-url@0.2.1: https://github.com/lydell/resolve-url#deprecated
# ⠙npm warn deprecated are-we-there-yet@3.0.1: This package is no longer supported.
# ⠹npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠹npm warn deprecated source-map-resolve@0.5.3: See https://github.com/lydell/source-map-resolve#deprecated
# ⠹npm warn deprecated domexception@2.0.1: Use your platform's native DOMException instead
# ⠹npm warn deprecated w3c-hr-time@1.0.2: Use your platform's native performance.now() and performance.timeOrigin.
# ⠸⠼npm warn deprecated sane@4.1.0: some dependency vulnerabilities fixed, support for node < 10 dropped, and newer ECMAScript syntax/features added
# ⠼npm warn deprecated google-p12-pem@3.1.4: Package is no longer maintained
# ⠼⠴npm warn deprecated gauge@4.0.4: This package is no longer supported.
# ⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# added 704 packages in 32s
# ⠙
# ⠙52 packages are looking for funding
# ⠙  run `npm fund` for details
# ⠙1.7.1

# %%
# %sql postgresql://postgres:test@postgres:5432/sahuagin
# Out:
# Connecting to 'postgresql://postgres:***@postgres:5432/sahuagin'

# %%
# %%sql
#
# CREATE OR REPLACE FUNCTION run_test_1()
#   RETURNS TEXT
# AS $$
# DECLARE
#   race        integer;
#   gender      integer;
#   male        integer;
#   female      integer;
#   hair_color  integer;
#   blonde      integer;
#   brown       integer;
#   golden      integer;
#   auburn      integer;
#   ginger      integer;
#   sandy       integer;
#   black       integer;
#   gray        integer;
#   height      integer;
#   short       integer;
#   average     integer;
#   tall        integer;
#   human       integer;
#   human_gender  integer;
#   human_hair_color  integer;
#   human_height  integer;
#   human_red_hair_to_height_var  integer;
#   test_humans integer;
# BEGIN
#   CALL add_discrete_attribute('Gender', gender);
#   CALL add_disc_span_to_attr(gender, 'Male', male);
#   CALL add_disc_span_to_attr(gender, 'Female', female);
#
#   CALL add_discrete_attribute('Hair Color', hair_color);
#   CALL add_disc_span_to_attr(hair_color, 'Blonde', blonde);
#   CALL add_disc_span_to_attr(hair_color, 'Brown', brown);
#   CALL add_disc_span_to_attr(hair_color, 'Golden', golden);
#   CALL add_disc_span_to_attr(hair_color, 'Auburn', auburn);
#   CALL add_disc_span_to_attr(hair_color, 'Ginger', ginger);
#   CALL add_disc_span_to_attr(hair_color, 'Sandy', sandy);
#   CALL add_disc_span_to_attr(hair_color, 'Black', black);
#   CALL add_disc_span_to_attr(hair_color, 'Gray', gray);
#   CALL modify_disc_span_weight(brown, .5);
#   CALL modify_disc_span_weight(gray, .05);
#
#   -- add_continuous_attribute(name, min, mode, max, concentration, skew, precision, show_spans, show_value, units, out p_attr_id)
#   CALL add_continuous_attribute('Height', 0, 222, 1000, 100000, 0, 4, TRUE, TRUE, 'in.', height);
#   CALL add_cont_span_to_attr(height, 'Short', 0, 100, short);
#   CALL add_cont_span_to_attr(height, 'Average', 100, 400, average);
#   CALL add_cont_span_to_attr(height, 'Tall', 400, 1000, tall);
#
#   CALL add_variant('Human', human);
#   CALL link_attr_to_variant(human, gender, 'Gender', NULL, human_gender);
#   CALL link_attr_to_variant(human, hair_color, 'Hair Color', NULL, human_hair_color);
#   CALL link_attr_to_variant(human, height, 'Height', NULL, human_height);
#
#   CALL add_variation(ginger, NULL, human_hair_color, NULL, human_height, human_red_hair_to_height_var);
#
#   CALL generate_entity_group(human, 'Test Humans', 'Human %s', 100, test_humans);
#   RETURN get_entity_group_state_details(test_humans);
# END;
# $$ LANGUAGE plpgsql;
#
# SELECT * FROM run_test_1()
# Out:
# Running query in 'postgresql://postgres:***@postgres:5432/sahuagin'
# RuntimeError: (psycopg2.errors.UndefinedFunction) procedure add_discrete_attribute(unknown, integer) does not exist
# LINE 1: CALL add_discrete_attribute('Gender', gender)
#              ^
# HINT:  No procedure matches the given name and argument types. You might need to add explicit type casts.
# QUERY:  CALL add_discrete_attribute('Gender', gender)
# CONTEXT:  PL/pgSQL function run_test_1() line 27 at CALL
#
# [SQL: SELECT * FROM run_test_1()]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# If you need help solving this issue, send us a message: https://ploomber.io/community
